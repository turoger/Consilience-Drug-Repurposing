# %% [markdown]
# # Run TransE algorithm on MIND-CiD dataset
# ## Parameters:
# * batch_size: 224
# * hidden_dimension_size: 275
# * learning_rate: 0.00109
# * negative_sample_size: 80
#
# ## Code for Hyperparameter Optimization
# ```python
# # Code for Generating MCiD best trials
# storage = optuna.storages.RDBStorage(
#     url="postgresql+psycopg2://rogertu:admin@localhost/optuna_test",
# )
# mctd_transe = optuna.load_study(study_name = 'TransE_MIND_CiD', storage = storage)
# mctd_transe.best_trial
# ```
#
# ## Results
# ```
# {'batch_size': 224,
#  'hidden_dimension_size': 275,
#  'learning_rate': 0.001095056356942874,
#  'max_steps': 90000,
#  'negative_sample_size': 80}
#
# [FrozenTrial(number=91, values=[0.03453757850139067], datetime_start=datetime.datetime(2022, 10, 26, 14, 39, 12, 620), datetime_complete=datetime.datetime(2022, 10, 26, 15, 49, 30, 888690), params={'batch_size': 224, 'negative_sample_size': 80, 'hidden_dimension_size': 275, 'learning_rate': 0.001095056356942874, 'max_steps': 90000}, distributions={'batch_size': IntDistribution(high=256, log=False, low=64, step=4), 'negative_sample_size': IntDistribution(high=128, log=False, low=64, step=4), 'hidden_dimension_size': IntDistribution(high=300, log=False, low=100, step=25), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'max_steps': IntDistribution(high=100000, log=False, low=50000, step=10000)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=1187, state=TrialState.COMPLETE, value=None)]
# ```

# %%
import os
os.chdir('..')

# %%
# Batch Sz/ Neg_samp_Sz/ Dims/ gamma/ alpha/ lr/ steps/ test batch size/ double ent/ double rel/ regularization
# !bash run.sh train TransE MIND_CiD 0 optimized 224 80 275 48.0 1.0 0.0011 1000000 16
# Out:
# 1.12.1+cu102
# Start Training......
# 2022-11-07 15:26:52,942 INFO     Model: TransE
# 2022-11-07 15:26:52,943 INFO     Data Path: data/MIND_CiD
# 2022-11-07 15:26:52,943 INFO     #entity: 249605
# 2022-11-07 15:26:52,943 INFO     #relation: 82
# 2022-11-07 15:26:58,360 INFO     #train: 9657134
# 2022-11-07 15:26:58,361 INFO     #valid: 473
# 2022-11-07 15:26:58,362 INFO     #test: 511
# 2022-11-07 15:26:59,219 INFO     Model Parameter Configuration:
# 2022-11-07 15:26:59,219 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2022-11-07 15:26:59,219 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2022-11-07 15:26:59,219 INFO     Parameter entity_embedding: torch.Size([249605, 275]), require_grad = True
# 2022-11-07 15:26:59,219 INFO     Parameter relation_embedding: torch.Size([82, 275]), require_grad = True
# 2022-11-07 15:27:58,262 INFO     Ramdomly Initializing TransE Model...
# 2022-11-07 15:27:58,262 INFO     Start Training...
# ...

# %%
# Batch Sz/ Neg_samp_Sz/ Dims/ gamma/ alpha/ lr/ steps/ test batch size/ double ent/ double rel/ regularization
# !bash run.sh train TransE MIND_CiD 0 optimized 224 80 275 48.0 1.0 0.0011 1000000 16 -init models/TransE_MIND_CiD_optimized/
# Out:
# 1.12.1+cu102
# Start Training......
# 2022-11-08 09:12:41,762 INFO     Model: TransE
# 2022-11-08 09:12:41,762 INFO     Data Path: data/MIND_CiD
# 2022-11-08 09:12:41,762 INFO     #entity: 249605
# 2022-11-08 09:12:41,762 INFO     #relation: 82
# 2022-11-08 09:12:47,254 INFO     #train: 9657134
# 2022-11-08 09:12:47,256 INFO     #valid: 473
# 2022-11-08 09:12:47,257 INFO     #test: 511
# 2022-11-08 09:12:48,012 INFO     Model Parameter Configuration:
# 2022-11-08 09:12:48,012 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2022-11-08 09:12:48,012 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2022-11-08 09:12:48,012 INFO     Parameter entity_embedding: torch.Size([249605, 275]), require_grad = True
# 2022-11-08 09:12:48,012 INFO     Parameter relation_embedding: torch.Size([82, 275]), require_grad = True
# 2022-11-08 09:13:49,384 INFO     Loading checkpoint models/TransE_MIND_CiD_optimized/...
# ...
