# %% [markdown]
# # Run TransE algorithm on MIND dataset
# ## Parameters:
# * batch_size: 236
# * hidden_dimension_size: 275
# * learning_rate: 0.0017
# * negative_sample_size: 72
#
# ## Code for Hyperparameter Optimization
# ```python
# # Code for Generating MCtD best trials
# storage = optuna.storages.RDBStorage(
#     url="postgresql+psycopg2://rogertu:admin@localhost/optuna_test",
# )
# mind_transe = optuna.load_study(study_name = 'TransE_MIND2', storage = storage)
# mind_transe.best_trial
# ```
#
# ## Results
# ```
# {'batch_size': 236,
#  'hidden_dimension_size': 275,
#  'learning_rate': 0.0017178667157871329,
#  'max_steps': 100000,
#  'negative_sample_size': 72}
# ```
# ```
# FrozenTrial(number=94, values=[0.023976627278024756], datetime_start=datetime.datetime(2022, 11, 12, 7, 12, 54, 595494), datetime_complete=datetime.datetime(2022, 11, 12, 7, 42, 46, 732162), params={'batch_size': 236, 'hidden_dimension_size': 275, 'learning_rate': 0.0017178667157871329, 'max_steps': 100000, 'negative_sample_size': 72}, distributions={'batch_size': IntDistribution(high=256, log=False, low=64, step=4), 'hidden_dimension_size': IntDistribution(high=300, log=False, low=100, step=25), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'max_steps': IntDistribution(high=100000, log=False, low=50000, step=10000), 'negative_sample_size': IntDistribution(high=128, log=False, low=64, step=4)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=1903, state=TrialState.COMPLETE, value=None)
# ```

# %%
import os
os.chdir('..')

# %%
# Batch Sz/ Neg_samp_Sz/ Dims/ gamma/ alpha/ lr/ steps/ test batch size/ double ent/ double rel/ regularization
# !bash run.sh train TransE MIND 0 optimized 236 72 275 48.0 1.0 0.0017 1000000 16
# Out:
# 1.12.1+cu102
# Start Training......
# 2022-11-13 22:49:47,032 INFO     Model: TransE
# 2022-11-13 22:49:47,032 INFO     Data Path: data/MIND
# 2022-11-13 22:49:47,032 INFO     #entity: 247456
# 2022-11-13 22:49:47,033 INFO     #relation: 82
# 2022-11-13 22:49:55,515 INFO     #train: 9592101
# 2022-11-13 22:49:55,518 INFO     #valid: 473
# 2022-11-13 22:49:55,519 INFO     #test: 535
# 2022-11-13 22:49:57,236 INFO     Model Parameter Configuration:
# 2022-11-13 22:49:57,236 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2022-11-13 22:49:57,236 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2022-11-13 22:49:57,236 INFO     Parameter entity_embedding: torch.Size([247456, 275]), require_grad = True
# 2022-11-13 22:49:57,237 INFO     Parameter relation_embedding: torch.Size([82, 275]), require_grad = True
# 2022-11-13 22:51:03,631 INFO     Ramdomly Initializing TransE Model...
# 2022-11-13 22:51:03,631 INFO     Start Training...
# ...
