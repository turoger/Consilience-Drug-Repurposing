# %% [markdown]
# # Fix MIND-CtD relation names
# * This notebook focuses on fixing indication relations and the types associated with each metanode.
# * Previously there was issues with incorrect node type assignments appeneded to the relations.
# * This notebook will serve to double check the node type assignments, as well as check for duplicates, and re-map some

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Fix MIND-CtD relations

# %%
train = pd.read_csv("../data/MIND_CtD/train.txt", names=["h", "r", "t"], sep="\t")
test = pd.read_csv("../data/MIND_CtD/test.txt", names=["h", "r", "t"], sep="\t")
valid = pd.read_csv("../data/MIND_CtD/valid.txt", names=["h", "r", "t"], sep="\t")

# %%
train['r2'] = train["r"].apply(lambda x: re.match("[a-z_]*[a-z]", x)[0])
train.head()
# Out:
#                  h              r              t        r2
# 0  UNII:BTY153760O  inhibits_CinG  NCBIGene:3605  inhibits
# 1    NCBIGene:4116  part_of_GpoBP     GO:0003723   part_of
# 2    NCBIGene:4116  part_of_GpoBP     GO:0005515   part_of
# 3    NCBIGene:4116   part_of_GpoA     GO:0005634   part_of
# 4    NCBIGene:4116   part_of_GpoA     GO:0005737   part_of

# %%
train["set"] = "train"
test["set"] = "test"
valid["set"] = "valid"

graph = pd.concat([train, test, valid])

# %%
# import nodes
nodes = pd.read_csv("/home/rogertu/MRN_dataset/nodes_biolink.csv")
nodes.head()
# Out:
# /tmp/ipykernel_2684481/3467899470.py:2: DtypeWarning: Columns (4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   nodes = pd.read_csv("/home/rogertu/MRN_dataset/nodes_biolink.csv")
#                id                       name             label  \
# 0  UBERON:0000002                     cervix  AnatomicalEntity
# 1  UBERON:0000004                 human nose  AnatomicalEntity
# 2  UBERON:0000006        islet of Langerhans  AnatomicalEntity
# 3  UBERON:0000007            pituitary gland  AnatomicalEntity
# 4  UBERON:0000010  peripheral nervous system  AnatomicalEntity
#
#                          xrefs source synonyms alt_ids subsets
# 0  MESH:D002584|UBERON:0000002    NaN      NaN     NaN     NaN
# 1  MESH:D009666|UBERON:0000004    NaN      NaN     NaN     NaN
# 2  MESH:D007515|UBERON:0000006    NaN      NaN     NaN     NaN
# 3  MESH:D010902|UBERON:0000007    NaN      NaN     NaN     NaN
# 4  MESH:D017933|UBERON:0000010    NaN      NaN     NaN     NaN

# %%
# expand nodes
# split xrefs by '|' and create a id to xref dictionary to map any diseases to later
nodes_noxrefs = nodes.query("xrefs!=xrefs")

nodes_xrefs = nodes.query("xrefs==xrefs")
nodes_xrefs["xrefs_expand"] = nodes_xrefs["xrefs"].apply(lambda x: x.split("|"))
nodes_xrefs = nodes_xrefs[["id", "label", "xrefs_expand"]].explode("xrefs_expand")
nodes_xrefs = nodes_xrefs.rename(columns={"xrefs_expand": "xrefs"})

nodes = pd.concat([nodes_noxrefs[["id", "label", "xrefs"]], nodes_xrefs])
nodes.head()
# Out:
# /tmp/ipykernel_2684481/3691727142.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nodes_xrefs["xrefs_expand"] = nodes_xrefs["xrefs"].apply(lambda x: x.split("|"))
#                 id             label xrefs
# 8   UBERON:0000016  AnatomicalEntity   NaN
# 9   UBERON:0000017  AnatomicalEntity   NaN
# 10  UBERON:0000018  AnatomicalEntity   NaN
# 11  UBERON:0000019  AnatomicalEntity   NaN
# 12  UBERON:0000020  AnatomicalEntity   NaN

# %%
nodee2label = dict(zip(nodes["id"], nodes["label"]))

# %% [markdown]
# ### Map start and end node to a label

# %%
graph["hlabel"] = graph["h"].apply(lambda x: nodee2label[x])
graph["tlabel"] = graph["t"].apply(lambda x: nodee2label[x])
graph.head()
# Out:
#                  h              r              t        r2    set  \
# 0  UNII:BTY153760O  inhibits_CinG  NCBIGene:3605  inhibits  train
# 1    NCBIGene:4116  part_of_GpoBP     GO:0003723   part_of  train
# 2    NCBIGene:4116  part_of_GpoBP     GO:0005515   part_of  train
# 3    NCBIGene:4116   part_of_GpoA     GO:0005634   part_of  train
# 4    NCBIGene:4116   part_of_GpoA     GO:0005737   part_of  train
#
#                   hlabel                       tlabel
# 0      ChemicalSubstance        MacromolecularMachine
# 1  MacromolecularMachine  BiologicalProcessOrActivity
# 2  MacromolecularMachine  BiologicalProcessOrActivity
# 3  MacromolecularMachine             AnatomicalEntity
# 4  MacromolecularMachine             AnatomicalEntity

# %% [markdown]
# ### get relations

# %%
graph["rel"] = graph["r"].apply(lambda x: re.match("[a-z_]*[a-z]", x)[0])
graph.head()
# Out:
#                  h              r              t        r2    set  \
# 0  UNII:BTY153760O  inhibits_CinG  NCBIGene:3605  inhibits  train
# 1    NCBIGene:4116  part_of_GpoBP     GO:0003723   part_of  train
# 2    NCBIGene:4116  part_of_GpoBP     GO:0005515   part_of  train
# 3    NCBIGene:4116   part_of_GpoA     GO:0005634   part_of  train
# 4    NCBIGene:4116   part_of_GpoA     GO:0005737   part_of  train
#
#                   hlabel                       tlabel       rel
# 0      ChemicalSubstance        MacromolecularMachine  inhibits
# 1  MacromolecularMachine  BiologicalProcessOrActivity   part_of
# 2  MacromolecularMachine  BiologicalProcessOrActivity   part_of
# 3  MacromolecularMachine             AnatomicalEntity   part_of
# 4  MacromolecularMachine             AnatomicalEntity   part_of

# %% [markdown]
# ### Map REACT/KEGG indications to diseases

# %%
graph["tsource"] = graph["t"].apply(lambda x: x.split(":")[0])

graph_kegg = graph.query('tsource=="KEGG"')
graph_notkegg = graph.query('tsource!="KEGG"')

# %%
graph_kegg["new_t"] = graph_kegg["t"].apply(
    lambda x: x.split("hsa")[0] + x.split("hsa")[1]
)
graph_kegg.head()
# Out:
# /tmp/ipykernel_2684481/1395742482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   graph_kegg["new_t"] = graph_kegg["t"].apply(
#                                         h                      r  \
# 3017856  IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3017857  IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3017858  IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3017859  IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3017860  IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
#
#                      t               r2    set             hlabel   tlabel  \
# 3017856  KEGG:hsa04510  associated_with  train  ChemicalSubstance  Pathway
# 3017857  KEGG:hsa04068  associated_with  train  ChemicalSubstance  Pathway
# 3017858  KEGG:hsa04012  associated_with  train  ChemicalSubstance  Pathway
# 3017859  KEGG:hsa05231  associated_with  train  ChemicalSubstance  Pathway
# 3017860  KEGG:hsa04062  associated_with  train  ChemicalSubstance  Pathway
#
#                      rel tsource       new_t
# 3017856  associated_with    KEGG  KEGG:04510
# 3017857  associated_with    KEGG  KEGG:04068
# 3017858  associated_with    KEGG  KEGG:04012
# 3017859  associated_with    KEGG  KEGG:05231
# 3017860  associated_with    KEGG  KEGG:04062

# %%
graph_kegg.shape
# Out:
# (400482, 10)

# %%
graph_kegg = pd.merge(
    left=graph_kegg,
    right=nodes[["id", "xrefs"]],
    left_on="new_t",
    right_on="xrefs",
    how="left",
)

graph_kegg
# Out:
#                                        h                      r  \
# 0       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 1       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 2       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 4       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# ...                                  ...                    ...
# 400477                       CHEBI:79699        indication_CiPW
# 400478                       CHEBI:41774        indication_CiPW
# 400479                       CHEBI:45863        indication_CiPW
# 400480                       CHEBI:50924        indication_CiPW
# 400481                        CHEBI:9168        indication_CiPW
#
#                     t               r2    set             hlabel   tlabel  \
# 0       KEGG:hsa04510  associated_with  train  ChemicalSubstance  Pathway
# 1       KEGG:hsa04068  associated_with  train  ChemicalSubstance  Pathway
# 2       KEGG:hsa04012  associated_with  train  ChemicalSubstance  Pathway
# 3       KEGG:hsa05231  associated_with  train  ChemicalSubstance  Pathway
# 4       KEGG:hsa04062  associated_with  train  ChemicalSubstance  Pathway
# ...               ...              ...    ...                ...      ...
# 400477  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
# 400478  KEGG:hsa05224              NaN  valid  ChemicalSubstance  Pathway
# 400479  KEGG:hsa05224              NaN  valid  ChemicalSubstance  Pathway
# 400480  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
# 400481  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
#
#                     rel tsource       new_t   id xrefs
# 0       associated_with    KEGG  KEGG:04510  NaN   NaN
# 1       associated_with    KEGG  KEGG:04068  NaN   NaN
# 2       associated_with    KEGG  KEGG:04012  NaN   NaN
# 3       associated_with    KEGG  KEGG:05231  NaN   NaN
# 4       associated_with    KEGG  KEGG:04062  NaN   NaN
# ...                 ...     ...         ...  ...   ...
# 400477       indication    KEGG  KEGG:05211  NaN   NaN
# 400478       indication    KEGG  KEGG:05224  NaN   NaN
# 400479       indication    KEGG  KEGG:05224  NaN   NaN
# 400480       indication    KEGG  KEGG:05211  NaN   NaN
# 400481       indication    KEGG  KEGG:05211  NaN   NaN
#
# [400482 rows x 12 columns]

# %%
# Only diseases in the id column
set(graph_kegg.dropna(subset="id")["id"].apply(lambda x: x.split(":")[0]))
# Out:
# set()

# %%
set(graph_kegg["tlabel"])
# Out:
# {'Pathway'}

# %%
tmp_ls = list()  # new 't' if its not empty, otherwise old 't'
tmp_ls2 = list()  #

for i, v in enumerate(graph_kegg["id"]):
    if type(v) == float:
        tmp_ls.append(graph_kegg["t"][i])
        tmp_ls2.append("Pathway")
    else:
        tmp_ls.append(v)
        tmp_ls2.append("Disease")

# %%
graph_kegg["t"] = tmp_ls
graph_kegg["tlabel"] = tmp_ls2
graph_kegg
# Out:
#                                        h                      r  \
# 0       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 1       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 2       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 3       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# 4       IKEY:AXTAPYRUEKNRBA-JTQLQIEISA-N  associated_with_CawPW
# ...                                  ...                    ...
# 400477                       CHEBI:79699        indication_CiPW
# 400478                       CHEBI:41774        indication_CiPW
# 400479                       CHEBI:45863        indication_CiPW
# 400480                       CHEBI:50924        indication_CiPW
# 400481                        CHEBI:9168        indication_CiPW
#
#                     t               r2    set             hlabel   tlabel  \
# 0       KEGG:hsa04510  associated_with  train  ChemicalSubstance  Pathway
# 1       KEGG:hsa04068  associated_with  train  ChemicalSubstance  Pathway
# 2       KEGG:hsa04012  associated_with  train  ChemicalSubstance  Pathway
# 3       KEGG:hsa05231  associated_with  train  ChemicalSubstance  Pathway
# 4       KEGG:hsa04062  associated_with  train  ChemicalSubstance  Pathway
# ...               ...              ...    ...                ...      ...
# 400477  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
# 400478  KEGG:hsa05224              NaN  valid  ChemicalSubstance  Pathway
# 400479  KEGG:hsa05224              NaN  valid  ChemicalSubstance  Pathway
# 400480  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
# 400481  KEGG:hsa05211              NaN  valid  ChemicalSubstance  Pathway
#
#                     rel tsource       new_t   id xrefs
# 0       associated_with    KEGG  KEGG:04510  NaN   NaN
# 1       associated_with    KEGG  KEGG:04068  NaN   NaN
# 2       associated_with    KEGG  KEGG:04012  NaN   NaN
# 3       associated_with    KEGG  KEGG:05231  NaN   NaN
# 4       associated_with    KEGG  KEGG:04062  NaN   NaN
# ...                 ...     ...         ...  ...   ...
# 400477       indication    KEGG  KEGG:05211  NaN   NaN
# 400478       indication    KEGG  KEGG:05224  NaN   NaN
# 400479       indication    KEGG  KEGG:05224  NaN   NaN
# 400480       indication    KEGG  KEGG:05211  NaN   NaN
# 400481       indication    KEGG  KEGG:05211  NaN   NaN
#
# [400482 rows x 12 columns]

# %%
graph = pd.concat(
    [
        graph_notkegg,
        graph_kegg[["h", "r", "t", "set", "hlabel", "tlabel", "rel", "tsource"]],
    ]
)
graph
# Out:
#                       h                r              t        r2    set  \
# 0       UNII:BTY153760O    inhibits_CinG  NCBIGene:3605  inhibits  train
# 1         NCBIGene:4116    part_of_GpoBP     GO:0003723   part_of  train
# 2         NCBIGene:4116    part_of_GpoBP     GO:0005515   part_of  train
# 3         NCBIGene:4116     part_of_GpoA     GO:0005634   part_of  train
# 4         NCBIGene:4116     part_of_GpoA     GO:0005737   part_of  train
# ...                 ...              ...            ...       ...    ...
# 400477      CHEBI:79699  indication_CiPW  KEGG:hsa05211       NaN  valid
# 400478      CHEBI:41774  indication_CiPW  KEGG:hsa05224       NaN  valid
# 400479      CHEBI:45863  indication_CiPW  KEGG:hsa05224       NaN  valid
# 400480      CHEBI:50924  indication_CiPW  KEGG:hsa05211       NaN  valid
# 400481       CHEBI:9168  indication_CiPW  KEGG:hsa05211       NaN  valid
#
#                        hlabel                       tlabel         rel  \
# 0           ChemicalSubstance        MacromolecularMachine    inhibits
# 1       MacromolecularMachine  BiologicalProcessOrActivity     part_of
# 2       MacromolecularMachine  BiologicalProcessOrActivity     part_of
# 3       MacromolecularMachine             AnatomicalEntity     part_of
# 4       MacromolecularMachine             AnatomicalEntity     part_of
# ...                       ...                          ...         ...
# 400477      ChemicalSubstance                      Pathway  indication
# 400478      ChemicalSubstance                      Pathway  indication
# 400479      ChemicalSubstance                      Pathway  indication
# 400480      ChemicalSubstance                      Pathway  indication
# 400481      ChemicalSubstance                      Pathway  indication
#
#          tsource
# 0       NCBIGene
# 1             GO
# 2             GO
# 3             GO
# 4             GO
# ...          ...
# 400477      KEGG
# 400478      KEGG
# 400479      KEGG
# 400480      KEGG
# 400481      KEGG
#
# [9658118 rows x 9 columns]

# %% [markdown]
# ### Replace REACT:R-HSA-2160456 with DOID:9281.

# %%
graph.query('t=="REACT:R-HSA-2160456"').index
# Out:
# Int64Index([], dtype='int64')

# %%
graph.query('t=="REACT:R-HSA-2160456"')
# Out:
# Empty DataFrame
# Columns: [h, r, t, r2, set, hlabel, tlabel, rel, tsource]
# Index: []

# %%
graph.loc()[9646746]
# Out:
# h                  MESH:D001555
# r          associated_with_CawD
# t                     DOID:9744
# r2              associated_with
# set                       train
# hlabel        ChemicalSubstance
# tlabel                  Disease
# rel             associated_with
# tsource                    DOID
# Name: 9646746, dtype: object

# %%
for i in list(graph.query('t=="REACT:R-HSA-2160456"').index):
    graph.t.loc()[i] = "DOID:9281"
    graph.tlabel.loc()[i] = "Disease"

graph.query('t=="REACT:R-HSA-2160456"')
# Out:
# Empty DataFrame
# Columns: [h, r, t, r2, set, hlabel, tlabel, rel, tsource]
# Index: []

# %% [markdown]
# ## Generate new relation labels

# %%
node_types = {
    "ChemicalSubstance": "C",
    "MacromolecularMachine": "G",
    "BiologicalProcessOrActivity": "BP",
    "Disease": "D",
    "AnatomicalEntity": "A",
    "PhenotypicFeature": "P",
    "Pathway": "PW",
    "OrganismTaxon": "T",
    "GeneFamily": "F",
}

rel_type = {
    "inhibits": "in",
    "activates": "a",
    "affects": "af",
    "associated_with": "aw",
    "causes": "c",
    "disrupts": "d",
    "part_of": "po",
    "in_taxon": "it",
    "site_of": "so",
    "presents": "ps",
    "treats": "t",
    "regulates": "r",
    "capable_of": "co",
    "produces": "p",
    "has_input": "hi",
    "negatively_regulates": "nr",
    "positively_regulates": "pr",
    "in_reaction_with": "rx",
    "palliates": "pl",
    "prevents": "pv",
    "marker_or_mechanism": "m",
    "indication": "i",
}

# %%
graph.head()
# Out:
#                  h              r              t        r2    set  \
# 0  UNII:BTY153760O  inhibits_CinG  NCBIGene:3605  inhibits  train
# 1    NCBIGene:4116  part_of_GpoBP     GO:0003723   part_of  train
# 2    NCBIGene:4116  part_of_GpoBP     GO:0005515   part_of  train
# 3    NCBIGene:4116   part_of_GpoA     GO:0005634   part_of  train
# 4    NCBIGene:4116   part_of_GpoA     GO:0005737   part_of  train
#
#                   hlabel                       tlabel       rel   tsource
# 0      ChemicalSubstance        MacromolecularMachine  inhibits  NCBIGene
# 1  MacromolecularMachine  BiologicalProcessOrActivity   part_of        GO
# 2  MacromolecularMachine  BiologicalProcessOrActivity   part_of        GO
# 3  MacromolecularMachine             AnatomicalEntity   part_of        GO
# 4  MacromolecularMachine             AnatomicalEntity   part_of        GO

# %%
graph["new_r"] = (
    graph["rel"]
    + "_"
    + graph["hlabel"].apply(lambda x: node_types[x])
    + graph["rel"].apply(lambda x: rel_type[x])
    + graph["tlabel"].apply(lambda x: node_types[x])
)

graph.head()
# Out:
#                  h              r              t        r2    set  \
# 0  UNII:BTY153760O  inhibits_CinG  NCBIGene:3605  inhibits  train
# 1    NCBIGene:4116  part_of_GpoBP     GO:0003723   part_of  train
# 2    NCBIGene:4116  part_of_GpoBP     GO:0005515   part_of  train
# 3    NCBIGene:4116   part_of_GpoA     GO:0005634   part_of  train
# 4    NCBIGene:4116   part_of_GpoA     GO:0005737   part_of  train
#
#                   hlabel                       tlabel       rel   tsource  \
# 0      ChemicalSubstance        MacromolecularMachine  inhibits  NCBIGene
# 1  MacromolecularMachine  BiologicalProcessOrActivity   part_of        GO
# 2  MacromolecularMachine  BiologicalProcessOrActivity   part_of        GO
# 3  MacromolecularMachine             AnatomicalEntity   part_of        GO
# 4  MacromolecularMachine             AnatomicalEntity   part_of        GO
#
#            new_r
# 0  inhibits_CinG
# 1  part_of_GpoBP
# 2  part_of_GpoBP
# 3   part_of_GpoA
# 4   part_of_GpoA

# %% [markdown]
# ### Seperate into train, test, valid

# %%
graph[["h", "new_r", "t", "set"]].shape
# Out:
# (9658118, 4)

# %%
graph2=graph[['h','new_r','t','set']]

# %%
# sort values first prior to dropping duplicates
graph2["set"] = pd.Categorical(graph2["set"], ["train", "test", "valid"])
# Out:
# /tmp/ipykernel_2684481/2754380957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   graph2["set"] = pd.Categorical(graph2["set"], ["train", "test", "valid"])

# %%
graph2 = (graph2
    .sort_values(by="set")
    .drop_duplicates(subset=["h", "new_r", "t"])
)

# %%
graph2.shape
# Out:
# (9658118, 4)

# %%
train2 = graph2.query('set=="train"')[["h", "new_r", "t"]]
test2 = graph2.query('set=="test"')[["h", "new_r", "t"]]
valid2 = graph2.query('set=="valid"')[["h", "new_r", "t"]]

# %% [markdown]
# ### quick check on splits

# %%
pd.merge(
    left=train2, right=test2, on=["h", "new_r", "t"], how="outer", indicator=True
).groupby("_merge").count().reset_index()[["_merge", "h"]].rename(
    columns={"_merge": "dir", "h": "count"}
)
# Out:
#           dir    count
# 0   left_only  9657134
# 1  right_only      511
# 2        both        0

# %%
pd.merge(
    left=train2, right=valid2, on=["h", "new_r", "t"], how="outer", indicator=True
).groupby("_merge").count().reset_index()[["_merge", "h"]].rename(
    columns={"_merge": "dir", "h": "count"}
)
# Out:
#           dir    count
# 0   left_only  9657134
# 1  right_only      473
# 2        both        0

# %%
pd.merge(
    left=test2, right=valid2, on=["h", "new_r", "t"], how="outer", indicator=True
).groupby("_merge").count().reset_index()[["_merge", "h"]].rename(
    columns={"_merge": "dir", "h": "count"}
)
# Out:
#           dir  count
# 0   left_only    511
# 1  right_only    473
# 2        both      0

# %%
graph2.head()
# Out:
#                        h                  new_r              t    set
# 0        UNII:BTY153760O          inhibits_CinG  NCBIGene:3605  train
# 6838555       GO:0086100  associated_with_BPawD      DOID:3910  train
# 6838556       GO:0097009  associated_with_BPawD   DOID:0111704  train
# 6838557       GO:0097009  associated_with_BPawD      DOID:3910  train
# 6838558       GO:0086100  associated_with_BPawD       DOID:971  train

# %%
graph2.shape
# Out:
# (9658118, 4)

# %%
9658118-(511+473+9657134)
# Out:
# 0

# %%
graph2['r'] = graph2.new_r.apply(lambda x: re.findall('[a-z]+',x)[0])

# %%
graph2.query('r=="indication"')
# Out:
#                    h            new_r              t    set           r
# 9450278  CHEBI:22907   indication_CiD      DOID:3070  train  indication
# 9450279  CHEBI:22907   indication_CiD      DOID:8552  train  indication
# 9450280   CHEBI:2038   indication_CiD      DOID:8552  train  indication
# 9450281   CHEBI:2038   indication_CiD      DOID:3070  train  indication
# 9450282   CHEBI:2038   indication_CiD     DOID:10283  train  indication
# ...              ...              ...            ...    ...         ...
# 159      CHEBI:36691   indication_CiD     DOID:50433  valid  indication
# 158       CHEBI:3997   indication_CiD     DOID:50952  valid  indication
# 157      CHEBI:32181   indication_CiD      DOID:8552  valid  indication
# 155       CHEBI:6444   indication_CiD     DOID:60145  valid  indication
# 400481    CHEBI:9168  indication_CiPW  KEGG:hsa05211  valid  indication
#
# [5213 rows x 5 columns]

# %%
graph2.query('new_r=="treats_CtD"')
# Out:
#                                         h       new_r             t    set  \
# 6824409                      MESH:C474576  treats_CtD     DOID:9975  train
# 6824411                      MESH:C062458  treats_CtD      DOID:809  train
# 6824412                      MESH:C103477  treats_CtD     DOID:9975  train
# 6824414                        CHEBI:5784  treats_CtD  DOID:0070238  train
# 6824408                      MESH:C474576  treats_CtD      DOID:809  train
# ...                                   ...         ...           ...    ...
# 3698585  IKEY:XXRCUYVCPSWGCC-UHFFFAOYSA-N  treats_CtD  MESH:D019446  train
# 3698586  IKEY:XXRCUYVCPSWGCC-UHFFFAOYSA-N  treats_CtD  MESH:D007238  train
# 3698556                        CHEBI:4974  treats_CtD  MESH:D019694  train
# 3698559                       CHEBI:38677  treats_CtD  MESH:D002418  train
# 3698560                       CHEBI:38677  treats_CtD  MESH:D007411  train
#
#               r
# 6824409  treats
# 6824411  treats
# 6824412  treats
# 6824414  treats
# 6824408  treats
# ...         ...
# 3698585  treats
# 3698586  treats
# 3698556  treats
# 3698559  treats
# 3698560  treats
#
# [65009 rows x 5 columns]

# %%
graph2.query('r=="treats"')
# Out:
#                                         h       new_r             t    set  \
# 6824409                      MESH:C474576  treats_CtD     DOID:9975  train
# 6824411                      MESH:C062458  treats_CtD      DOID:809  train
# 6824412                      MESH:C103477  treats_CtD     DOID:9975  train
# 6824414                        CHEBI:5784  treats_CtD  DOID:0070238  train
# 6824408                      MESH:C474576  treats_CtD      DOID:809  train
# ...                                   ...         ...           ...    ...
# 3698586  IKEY:XXRCUYVCPSWGCC-UHFFFAOYSA-N  treats_CtD  MESH:D007238  train
# 3698587  IKEY:XXRCUYVCPSWGCC-UHFFFAOYSA-N  treats_CtP  MESH:D007249  train
# 3698556                        CHEBI:4974  treats_CtD  MESH:D019694  train
# 3698559                       CHEBI:38677  treats_CtD  MESH:D002418  train
# 3698560                       CHEBI:38677  treats_CtD  MESH:D007411  train
#
#               r
# 6824409  treats
# 6824411  treats
# 6824412  treats
# 6824414  treats
# 6824408  treats
# ...         ...
# 3698586  treats
# 3698587  treats
# 3698556  treats
# 3698559  treats
# 3698560  treats
#
# [71050 rows x 5 columns]

# %%
graph2.groupby('new_r').count()
# Out:
#                            h       t     set
# new_r
# activates_CaBP         38936   38936   38936
# activates_CaG         472943  472943  472943
# affects_CafBP          62523   62523   62523
# affects_CafG          924308  924308  924308
# associated_with_AawD  144217  144217  144217
# ...                      ...     ...     ...
# site_of_AsoPW           2610    2610    2610
# treats_CtD             65009   65009   65009
# treats_CtP              3360    3360    3360
# treats_GtD              2158    2158    2158
# treats_GtP               523     523     523
#
# [78 rows x 3 columns]

# %%
graph2.query('set=="train"')[["h", "new_r", "t"]].to_csv(
    "../data/MIND_CtD/train.txt", sep="\t", header=False, index=False
)
graph2.query('set=="test"')[["h", "new_r", "t"]].to_csv(
    "../data/MIND_CtD/test.txt", sep="\t", header=False, index=False
)
graph2.query('set=="valid"')[["h", "new_r", "t"]].to_csv(
    "../data/MIND_CtD/valid.txt", sep="\t", header=False, index=False
)
